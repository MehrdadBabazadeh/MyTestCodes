# %% [markdown]
# <a href="https://colab.research.google.com/github/MehrdadBabazadeh/MyTestCodes/blob/main/ECM_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install "pybamm[plot,cite]" -q    # install PyBaMM if it is not installed
import pybamm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.6/22.6 MB 38.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 15.7 MB/s eta 0:00:00

# %%
models = [
    #pybamm.lithium_ion.SPM(),
    #pybamm.lithium_ion.SPMe(),
    #pybamm.lithium_ion.DFN(),
    pybamm.equivalent_circuit.Thevenin(),
]

# %%
sims = []
for model in models:
    sim = pybamm.Simulation(model)
    sim.solve([0, 3600])
    sims.append(sim)

# %%
pybamm.dynamic_plot(sims, time_unit="seconds")
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1746.0952503009073, step=17.46095250300907),…
